# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
trdata=pd.read_csv('train.csv')
pd.set_option('display.max_columns',None)

# %%
trdata
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
trdata.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
plt.figure(figsize=(15,15))
sns.heatmap(trdata.isnull())
# Out:
# <AxesSubplot:>

# %%
trdata
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
trdata['Alley'].isnull().sum()
# Out:
# 1091

# %%
trdata['PoolQC'].isnull().sum()
# Out:
# 1161

# %%
trdata['Fence'].isnull().sum()
# Out:
# 931

# %%
trdata['MiscFeature'].isnull().sum()
# Out:
# 1124

# %% [markdown]
# since these columns have a lot of nan values,so we removing them

# %%
trdata.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(trdata.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# now lets handle the rest of the null values according to their catogorical types

# %%
trdata['FireplaceQu'].isnull().sum()
# Out:
# 551

# %%
trdata['LotFrontage'].isnull().sum()
# Out:
# 214

# %%
trdata['GarageType'].isnull().sum()
# Out:
# 64

# %%
trdata['GarageYrBlt'].isnull().sum()
# Out:
# 64

# %%
trdata['GarageQual'].isnull().sum()
# Out:
# 64

# %%
trdata['FireplaceQu']=trdata['FireplaceQu'].fillna(trdata['FireplaceQu'].mode()[0])
trdata['GarageType']=trdata['GarageType'].fillna(trdata['GarageType'].mode()[0])
trdata['GarageQual']=trdata['GarageQual'].fillna(trdata['GarageQual'].mode()[0])
trdata['GarageFinish']=trdata['GarageFinish'].fillna(trdata['GarageFinish'].mode()[0])
trdata['GarageCond']=trdata['GarageCond'].fillna(trdata['GarageCond'].mode()[0])
trdata['BsmtQual']=trdata['BsmtQual'].fillna(trdata['BsmtQual'].mode()[0])
trdata['BsmtCond']=trdata['BsmtCond'].fillna(trdata['BsmtCond'].mode()[0])
trdata['BsmtExposure']=trdata['BsmtExposure'].fillna(trdata['BsmtExposure'].mode()[0])
trdata['BsmtFinType1']=trdata['BsmtFinType1'].fillna(trdata['BsmtFinType1'].mode()[0])
trdata['BsmtFinType2']=trdata['BsmtFinType2'].fillna(trdata['BsmtFinType2'].mode()[0])
trdata['MasVnrType']=trdata['MasVnrType'].fillna(trdata['MasVnrType'].mode()[0])

# %%
trdata['LotFrontage']=trdata['LotFrontage'].replace(np.NAN,trdata['LotFrontage'].mean())
trdata['GarageYrBlt']=trdata['GarageYrBlt'].replace(np.NAN,trdata['GarageYrBlt'].mean())
trdata['MasVnrArea']=trdata['MasVnrArea'].replace(np.NAN,trdata['MasVnrArea'].mean())

# %%
plt.figure(figsize=(15,15))
sns.heatmap(trdata.isnull())
# Out:
# <AxesSubplot:>

# %%
trdata
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     127         120       RL     70.98847     4928   Pave      IR1
# 1     889          20       RL     95.00000    15865   Pave      IR1
# 2     793          60       RL     92.00000     9920   Pave      IR1
# 3     110          20       RL    105.00000    11751   Pave      IR1
# 4     422          20       RL     70.98847    16635   Pave      IR1
# ...   ...         ...      ...          ...      ...    ...      ...
# 1163  289          20       RL     70.98847     9819   Pave      IR1
# 1164  554          20       RL     67.00000     8777   Pave      Reg
# 1165  196         160       RL     24.00000     2280   Pave      Reg
# 1166   31          70  C (all)     50.00000     8500   Pave      Reg
# 1167  617          60       RL     70.98847     7861   Pave      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
sns.countplot(trdata['Street'])
# Out:
# <AxesSubplot:xlabel='Street', ylabel='count'>

# %%
sns.countplot(trdata['LandContour'])
# Out:
# <AxesSubplot:xlabel='LandContour', ylabel='count'>

# %%
plt.figure(figsize=(12,10))
sns.countplot(trdata['Utilities'])
# Out:
# <AxesSubplot:xlabel='Utilities', ylabel='count'>

# %%
trdata.drop('Utilities',axis=1,inplace=True)

# %%
plt.figure(figsize=(12,10))
sns.countplot(trdata['LotShape'])
# Out:
# <AxesSubplot:xlabel='LotShape', ylabel='count'>

# %%
plt.figure(figsize=(12,10))
sns.countplot(trdata['LotConfig'])
# Out:
# <AxesSubplot:xlabel='LotConfig', ylabel='count'>

# %%
plt.figure(figsize=(12,10))
sns.countplot(trdata['LandSlope'])
# Out:
# <AxesSubplot:xlabel='LandSlope', ylabel='count'>

# %%
plt.figure(figsize=(20,15))
sns.countplot(trdata['Neighborhood'])
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='count'>

# %%
for column in trdata.columns:
    if trdata[column].dtype==object:
        print(str(column)+":"+(str(trdata[column].unique())))
        print(trdata[column].value_counts())
        print("---------------------------------------")
# Out:
# MSZoning:['RL' 'RM' 'FV' 'RH' 'C (all)']
# RL         928
# RM         163
# FV          52
# RH          16
# C (all)      9
# Name: MSZoning, dtype: int64
# ---------------------------------------
# Street:['Pave' 'Grvl']
# Pave    1164
# Grvl       4
# Name: Street, dtype: int64
# ---------------------------------------
# LotShape:['IR1' 'Reg' 'IR2' 'IR3']
# Reg    740
# IR1    390
# IR2     32
# IR3      6
# Name: LotShape, dtype: int64
# ---------------------------------------
# LandContour:['Lvl' 'Bnk' 'HLS' 'Low']
# Lvl    1046
# Bnk      50
# HLS      42
# Low      30
# Name: LandContour, dtype: int64
# ---------------------------------------
# LotConfig:['Inside' 'CulDSac' 'FR2' 'Corner' 'FR3']
# Inside     842
# Corner     222
# CulDSac     69
# FR2         33
# FR3          2
# Name: LotConfig, dtype: int64
# ---------------------------------------
# LandSlope:['Gtl' 'Mod' 'Sev']
# Gtl    1105
# Mod      51
# Sev      12
# Name: LandSlope, dtype: int64
# ...

# %% [markdown]
# now lets convert the categorical data in numerical data using ordinal encoder

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord=OrdinalEncoder()
for i in trdata.columns:
    if trdata[i].dtype=='object':
        trdata[i]=ord.fit_transform(trdata[i].values.reshape(-1,1))

# %%
trdata
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     127         120       3.0     70.98847     4928     1.0       0.0
# 1     889          20       3.0     95.00000    15865     1.0       0.0
# 2     793          60       3.0     92.00000     9920     1.0       0.0
# 3     110          20       3.0    105.00000    11751     1.0       0.0
# 4     422          20       3.0     70.98847    16635     1.0       0.0
# ...   ...         ...       ...          ...      ...     ...       ...
# 1163  289          20       3.0     70.98847     9819     1.0       0.0
# 1164  554          20       3.0     67.00000     8777     1.0       3.0
# 1165  196         160       3.0     24.00000     2280     1.0       3.0
# 1166   31          70       0.0     50.00000     8500     1.0       3.0
# 1167  617          60       3.0     70.98847     7861     1.0       0.0
#
#       LandContour  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %%
corr_mat=trdata.corr()
plt.figure(figsize=[45,45])
sns.heatmap(corr_mat,annot=True,cmap='Blues')
plt.show()

# %%
corr_matrix=trdata.corr()
corr_matrix['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice       1.000000
# OverallQual     0.789185
# GrLivArea       0.707300
# GarageCars      0.628329
# GarageArea      0.619000
#                   ...
# HeatingQC      -0.406604
# GarageFinish   -0.537121
# KitchenQual    -0.592468
# ExterQual      -0.624820
# BsmtQual       -0.626850
# Name: SalePrice, Length: 76, dtype: float64

# %%
trdata.plot(kind='density',subplots=True,layout=(11,8),sharex=False,legend=False,fontsize=1,figsize=(15,12))
plt.show()

# %%
x=trdata.drop('SalePrice',axis=1)
y=trdata['SalePrice']

# %%
x.skew().sort_values(ascending=False)
# Out:
# MiscVal       23.065943
# PoolArea      13.243711
# Condition2    11.514458
# LotArea       10.659285
# Heating       10.103609
#                 ...
# SaleType      -3.660513
# Functional    -3.999663
# GarageQual    -4.582386
# GarageCond    -5.422472
# Street       -17.021969
# Length: 75, dtype: float64

# %%
from sklearn.preprocessing import power_transform

# %%
x_new=power_transform(x)

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual',
#        'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure',
#        'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
x
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# 0    -1.544968    1.370435 -0.162456     0.093658 -1.213954  0.058621
# 1     0.461941   -1.167999 -0.162456     1.117135  1.100521  0.058621
# 2     0.254221    0.490047 -0.162456     0.998803  0.158048  0.058621
# 3    -1.610857   -1.167999 -0.162456     1.495566  0.496002  0.058621
# 4    -0.635571   -1.167999 -0.162456     0.093658  1.196626  0.058621
# ...        ...         ...       ...          ...       ...       ...
# 1163 -1.008279   -1.167999 -0.162456     0.093658  0.137703  0.058621
# 1164 -0.299331   -1.167999 -0.162456    -0.096350 -0.084786  0.058621
# 1165 -1.300337    1.700798 -0.162456    -2.852857 -2.681835  0.058621
# 1166 -1.975680    0.696557 -2.926464    -0.996296 -0.148203  0.058621
# 1167 -0.147481    0.490047 -0.162456     0.093658 -0.302416  0.058621
#
#       LotShape  LandContour  LotConfig  LandSlope  Neighborhood  Condition1  \
# ...

# %%
x=pd.DataFrame(x_new,columns=x.columns)

# %%
x.skew().sort_values(ascending=False)
# Out:
# PoolArea        12.817372
# 3SsnPorch        7.087955
# LowQualFinSF     6.922843
# MiscVal          4.991071
# LandSlope        3.954345
#                   ...
# GarageQual      -4.327379
# Heating         -4.541694
# GarageCond      -4.925781
# RoofMatl        -6.314987
# Street         -17.021969
# Length: 75, dtype: float64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['variambles']=x.columns
    vif['VIf']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

# %%
calc_vif(x)
# Out:
#        variambles       VIf
# 0              Id  1.072406
# 1      MSSubClass  6.298729
# 2        MSZoning  1.448051
# 3     LotFrontage  2.153789
# 4         LotArea  2.715093
# ..            ...       ...
# 70        MiscVal  1.159399
# 71         MoSold  1.097146
# 72         YrSold  1.115651
# 73       SaleType  1.352411
# 74  SaleCondition  1.455946
#
# [75 rows x 2 columns]

# %%
trdata.drop('BsmtFinSF2',axis=1,inplace=True)

# %%
x.iloc[:,0:20].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
x.iloc[:,21:50].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
x.iloc[:,51:].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
from scipy.stats import zscore
z=np.abs(zscore(trdata))
z.shape
# Out:
# (1168, 75)

# %%
threshold=5
print(np.where(z))
# Out:
# (array([   0,    0,    0, ..., 1167, 1167, 1167], dtype=int64), array([ 0,  1,  2, ..., 72, 73, 74], dtype=int64))

# %%
new_trdata=trdata[(z<5).all(axis=1)]
print(trdata.shape)
print(new_trdata.shape)
# Out:
# (1168, 75)
# (1011, 75)

# %%
df_train=new_trdata

# %%
df_train
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0      127         120       3.0     70.98847     4928     1.0       0.0
# 2      793          60       3.0     92.00000     9920     1.0       0.0
# 3      110          20       3.0    105.00000    11751     1.0       0.0
# 4      422          20       3.0     70.98847    16635     1.0       0.0
# 5     1197          60       3.0     58.00000    14054     1.0       0.0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1161  1301          60       3.0     70.98847    10762     1.0       0.0
# 1163   289          20       3.0     70.98847     9819     1.0       0.0
# 1164   554          20       3.0     67.00000     8777     1.0       3.0
# 1165   196         160       3.0     24.00000     2280     1.0       3.0
# 1167   617          60       3.0     70.98847     7861     1.0       0.0
#
#       LandContour  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %%
df_train.skew()
# Out:
# Id              -0.001616
# MSSubClass       1.396510
# MSZoning        -1.704617
# LotFrontage      0.643117
# LotArea          2.222359
#                    ...
# MoSold           0.221382
# YrSold           0.109514
# SaleType        -3.650732
# SaleCondition   -2.756616
# SalePrice        1.353919
# Length: 75, dtype: float64

# %%
df_train
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0      127         120       3.0     70.98847     4928     1.0       0.0
# 2      793          60       3.0     92.00000     9920     1.0       0.0
# 3      110          20       3.0    105.00000    11751     1.0       0.0
# 4      422          20       3.0     70.98847    16635     1.0       0.0
# 5     1197          60       3.0     58.00000    14054     1.0       0.0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1161  1301          60       3.0     70.98847    10762     1.0       0.0
# 1163   289          20       3.0     70.98847     9819     1.0       0.0
# 1164   554          20       3.0     67.00000     8777     1.0       3.0
# 1165   196         160       3.0     24.00000     2280     1.0       3.0
# 1167   617          60       3.0     70.98847     7861     1.0       0.0
#
#       LandContour  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %% [markdown]
# now lets check the test data

# %%
tsdata=pd.read_csv('test.csv')

# %%
tsdata
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %%
tsdata.shape
# Out:
# (292, 80)

# %%
tsdata.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
tsdata['FireplaceQu']=tsdata['FireplaceQu'].fillna(tsdata['FireplaceQu'].mode()[0])
tsdata['GarageType']=tsdata['GarageType'].fillna(tsdata['GarageType'].mode()[0])
tsdata['GarageQual']=tsdata['GarageQual'].fillna(tsdata['GarageQual'].mode()[0])
tsdata['GarageFinish']=tsdata['GarageFinish'].fillna(tsdata['GarageFinish'].mode()[0])
tsdata['GarageCond']=tsdata['GarageCond'].fillna(tsdata['GarageCond'].mode()[0])
tsdata['BsmtQual']=tsdata['BsmtQual'].fillna(tsdata['BsmtQual'].mode()[0])
tsdata['BsmtCond']=tsdata['BsmtCond'].fillna(tsdata['BsmtCond'].mode()[0])
tsdata['BsmtExposure']=tsdata['BsmtExposure'].fillna(tsdata['BsmtExposure'].mode()[0])
tsdata['BsmtFinType1']=tsdata['BsmtFinType1'].fillna(tsdata['BsmtFinType1'].mode()[0])
tsdata['BsmtFinType2']=tsdata['BsmtFinType2'].fillna(tsdata['BsmtFinType2'].mode()[0])
tsdata['MasVnrType']=tsdata['MasVnrType'].fillna(tsdata['MasVnrType'].mode()[0])

# %%
tsdata['LotFrontage']=tsdata['LotFrontage'].replace(np.NAN,tsdata['LotFrontage'].mean())
tsdata['GarageYrBlt']=tsdata['GarageYrBlt'].replace(np.NAN,tsdata['GarageYrBlt'].mean())
tsdata['MasVnrArea']=tsdata['MasVnrArea'].replace(np.NAN,tsdata['MasVnrArea'].mean())

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ord=OrdinalEncoder()
for i in tsdata.columns:
    if tsdata[i].dtype=='object':
        tsdata[i]=ord.fit_transform(tsdata[i].values.reshape(-1,1))

# %%
tsdata
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0     337          20       2.0    86.000000    14157     1.0       0.0
# 1    1018         120       2.0    66.425101     5814     1.0       0.0
# 2     929          20       2.0    66.425101    11838     1.0       3.0
# 3    1148          70       2.0    75.000000    12000     1.0       3.0
# 4    1227          60       2.0    86.000000    14598     1.0       0.0
# ..    ...         ...       ...          ...      ...     ...       ...
# 287    83          20       2.0    78.000000    10206     1.0       3.0
# 288  1048          20       2.0    57.000000     9245     1.0       1.0
# 289    17          20       2.0    66.425101    11241     1.0       0.0
# 290   523          50       3.0    50.000000     5000     1.0       3.0
# 291  1379         160       3.0    21.000000     1953     1.0       3.0
#
#      LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# ...

# %%
x=df_train.drop('SalePrice',axis=1)
y=df_train['SalePrice']

# %%
x
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0      127         120       3.0     70.98847     4928     1.0       0.0
# 2      793          60       3.0     92.00000     9920     1.0       0.0
# 3      110          20       3.0    105.00000    11751     1.0       0.0
# 4      422          20       3.0     70.98847    16635     1.0       0.0
# 5     1197          60       3.0     58.00000    14054     1.0       0.0
# ...    ...         ...       ...          ...      ...     ...       ...
# 1161  1301          60       3.0     70.98847    10762     1.0       0.0
# 1163   289          20       3.0     70.98847     9819     1.0       0.0
# 1164   554          20       3.0     67.00000     8777     1.0       3.0
# 1165   196         160       3.0     24.00000     2280     1.0       3.0
# 1167   617          60       3.0     70.98847     7861     1.0       0.0
#
#       LandContour  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# ...

# %%
y
# Out:
# 0       128000
# 2       269790
# 3       190000
# 4       215000
# 5       219210
#          ...
# 1161    225000
# 1163    122000
# 1164    108000
# 1165    148500
# 1167    183200
# Name: SalePrice, Length: 1011, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=100)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.9120519068856473

# %%
predlr=lr.predict(x_test)

# %%
lr.score(x_test,y_test)
# Out:
# 0.8962892629915812

# %%
sns.distplot(predlr-y_test)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
xtr=ExtraTreesRegressor()
xtr.fit(x_train,y_train)
xtr.score(x_train,y_train)
# Out:
# 1.0

# %%
predxtr=xtr.predict(x_test)

# %%
sns.distplot(predxtr-y_test)
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
# Out:
# 0.9829591261752719

# %%
predrf=rf.predict(x_test)

# %%
plt.scatter(predrf,y_test)

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predrf,color="r")
plt.plot(y_test,y_test,color="b")
plt.title=("linear regression")
plt.show()

# %%
import pickle
filename="test.pkl"
pickle.dump(rf,open(filename,"wb"))
