# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sinha'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel("customer_retention_dataset.xlsx")

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.describe()
# Out:
#        4 What is the Pin Code of where you shop online from?
# count                                         269.000000
# mean                                       220465.747212
# std                                        140524.341051
# min                                        110008.000000
# 25%                                        122018.000000
# 50%                                        201303.000000
# 75%                                        201310.000000
# max                                        560037.000000

# %%
df.keys()
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
df.info
# Out:
# <bound method DataFrame.info of     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
df
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
df.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
df.count()
# Out:
# 1Gender of respondent                                                   269
# 2 How old are you?                                                      269
# 3 Which city do you shop online from?                                   269
# 4 What is the Pin Code of where you shop online from?                   269
# 5 Since How Long You are Shopping Online ?                              269
#                                                                        ...
# Longer delivery period                                                  269
# Change in website/Application design                                    269
# Frequent disruption when moving from one page to another                269
# Website is as efficient as before                                       269
# Which of the Indian online retailer would you recommend to a friend?    269
# Length: 71, dtype: int64

# %%
df.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
df1=df.drop(['4 What is the Pin Code of where you shop online from?','7 How do you access the internet while shopping on-line?','9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ','10 What is the operating system (OS) of your device?\t\t\t\t                                          ','11 What browser do you run on your device to access the website?\t\t\t                                                          '],axis=1)

# %%
df1
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# 265                             Ghaziabad
# ...

# %%
df2=df1.drop(["12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ","15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ","13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ","8 Which device do you use to access the online shopping?","14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ","16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ","3 Which city do you shop online from?"],axis=1)

# %%
df2
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     5 Since How Long You are Shopping Online ?  \
# 0                                Above 4 years
# 1                                Above 4 years
# 2                                    3-4 years
# 3                                    3-4 years
# 4                                    2-3 years
# ..                                         ...
# 264                                  1-2 years
# ...

# %%
df2.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ',
#        '18 The content on the website must be easy to read and understand',
#        '19 Information on similar product to the one highlighted  is important for product comparison',
#        '20 Complete information on listed seller and product being offered is important for purchase decision.',
#        '21 All relevant information on listed products must be stated clearly',
#        '22 Ease of navigation in website', '23 Loading and processing speed',
#        '24 User friendly Interface of the website',
#        '25 Convenient Payment methods',
# ...

# %%
df2
pd.set_option('display.max_columns',None)

# %%
df2
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     5 Since How Long You are Shopping Online ?  \
# 0                                Above 4 years
# 1                                Above 4 years
# 2                                    3-4 years
# 3                                    3-4 years
# 4                                    2-3 years
# ..                                         ...
# 264                                  1-2 years
# ...

# %%
sns.countplot(df2['1Gender of respondent'])
# Out:
# <AxesSubplot:xlabel='1Gender of respondent', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot(df2['2 How old are you? '])
# Out:
# <AxesSubplot:xlabel='2 How old are you? ', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot(df2['5 Since How Long You are Shopping Online ?'])
# Out:
# <AxesSubplot:xlabel='5 Since How Long You are Shopping Online ?', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot(df2['6 How many times you have made an online purchase in the past 1 year?'])
# Out:
# <AxesSubplot:xlabel='6 How many times you have made an online purchase in the past 1 year?', ylabel='count'>

# %%
plt.figure(figsize=(12,7))
sns.countplot(df2['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '])
# Out:
# <AxesSubplot:xlabel='17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ', ylabel='count'>

# %%
df2.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ',
#        '18 The content on the website must be easy to read and understand',
#        '19 Information on similar product to the one highlighted  is important for product comparison',
#        '20 Complete information on listed seller and product being offered is important for purchase decision.',
#        '21 All relevant information on listed products must be stated clearly',
#        '22 Ease of navigation in website', '23 Loading and processing speed',
#        '24 User friendly Interface of the website',
#        '25 Convenient Payment methods',
# ...

# %%
plt.figure(figsize=(12,7))
sns.countplot(df2['18 The content on the website must be easy to read and understand'])
# Out:
# <AxesSubplot:xlabel='18 The content on the website must be easy to read and understand', ylabel='count'>

# %%
plt.figure(figsize=(30,7))
sns.countplot(df2['Easy to use website or application'])
# Out:
# <AxesSubplot:xlabel='Easy to use website or application', ylabel='count'>

# %%
df2
# Out:
#     1Gender of respondent 2 How old are you?   \
# 0                    Male         31-40 years
# 1                  Female         21-30 years
# 2                  Female         21-30 years
# 3                    Male         21-30 years
# 4                  Female         21-30 years
# ..                    ...                 ...
# 264                Female         21-30 years
# 265                Female         31-40 years
# 266                Female         41-50 yaers
# 267                Female  Less than 20 years
# 268                Female         41-50 yaers
#
#     5 Since How Long You are Shopping Online ?  \
# 0                                Above 4 years
# 1                                Above 4 years
# 2                                    3-4 years
# 3                                    3-4 years
# 4                                    2-3 years
# ..                                         ...
# 264                                  1-2 years
# ...

# %% [markdown]
# now lets see some of the negative reviews of the costumers on the webstes

# %%
plt.figure(figsize=(20,7))
sns.countplot(df2['Longer time to get logged in (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Longer time to get logged in (promotion, sales period)', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(df2['Longer time in displaying graphics and photos (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Longer time in displaying graphics and photos (promotion, sales period)', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(df2['Late declaration of price (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Late declaration of price (promotion, sales period)', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(df2['Limited mode of payment on most products (promotion, sales period)'])
# Out:
# <AxesSubplot:xlabel='Limited mode of payment on most products (promotion, sales period)', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(df2['Longer delivery period'])
# Out:
# <AxesSubplot:xlabel='Longer delivery period', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(df2['Change in website/Application design'])
# Out:
# <AxesSubplot:xlabel='Change in website/Application design', ylabel='count'>

# %%
plt.figure(figsize=(20,7))
sns.countplot(df2['Frequent disruption when moving from one page to another'])
# Out:
# <AxesSubplot:xlabel='Frequent disruption when moving from one page to another', ylabel='count'>

# %% [markdown]
# now lets check the output variable

# %%
plt.figure(figsize=(30,7))
sns.countplot(df2['Which of the Indian online retailer would you recommend to a friend?'])
# Out:
# <AxesSubplot:xlabel='Which of the Indian online retailer would you recommend to a friend?', ylabel='count'>

# %% [markdown]
# as we can see that the amazon websitehas got highest number of reccomendation as compared to others
